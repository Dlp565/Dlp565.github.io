# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import requests as req
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as mpl

# %%
res = requests.get(url='https://mhanational.org/issues/2021/mental-health-america-all-data')

# %%
resB = BeautifulSoup(res.text)

# %%
tables = resB.findAll('table')

# %%
a = tables[3].findAll('tr')
for tr in a:
    td = tr.find("td")

# %%
for tr in tables[3].findAll('tr'):
    print(tr)
# Out:
# <tr>
# <th class="views-align-left views-field views-field-field-rank is-active views-align-left" id="view-field-rank-table-column--4" scope="col">Rank</th>
# <th class="views-align-left views-field views-field-field-state views-align-left" id="view-field-state-table-column--4" scope="col">State</th>
# <th class="views-align-left views-field views-field-field-percentage views-align-left" id="view-field-percentage-table-column--4" scope="col">Percentage</th>
# <th class="views-align-left views-field views-field-field-number views-align-left" id="view-field-number-table-column--4" scope="col">Number</th>
# </tr>
# <tr class="rankings">
# <td class="views-field views-field-field-rank is-active views-align-left" headers="view-field-rank-table-column--4">01          </td>
# <td class="views-field views-field-field-state views-align-left" headers="view-field-state-table-column--4">Maine          </td>
# ...

# %%
df = pd.read_csv('PLACES__Local_Data_for_Better_Health__Place_Data_2021_release.csv')

# %%
df
# Out:
#          Year StateAbbr  StateDesc  LocationName DataSource         Category  \
# 0        2019        AL    Alabama       Carlton      BRFSS  Health Outcomes
# 1        2019        AL    Alabama        Chatom      BRFSS  Health Outcomes
# 2        2019        AL    Alabama  Collinsville      BRFSS  Health Outcomes
# 3        2019        AL    Alabama        Colony      BRFSS  Health Outcomes
# 4        2019        AL    Alabama       Coosada      BRFSS  Health Outcomes
# ...       ...       ...        ...           ...        ...              ...
# 1685021  2019        WI  Wisconsin   Tunnel City      BRFSS       Prevention
# 1685022  2018        WY    Wyoming    Burlington      BRFSS       Prevention
# 1685023  2019        WY    Wyoming       Buffalo      BRFSS  Health Outcomes
# 1685024  2019        WI  Wisconsin        Waupun      BRFSS       Prevention
# 1685025  2018        WY    Wyoming        Alcova      BRFSS       Prevention
#
# ...

# %%
df['LocationName'].unique()
# Out:
# array(['Carlton', 'Chatom', 'Collinsville', ..., 'Lakeview North',
#        'Little America', 'Moorcroft'], dtype=object)

# %%
df.loc[(df['LocationName'] == 'Rockville') & (df['StateAbbr'] == 'MD')]
# Out:
#         Year StateAbbr StateDesc LocationName DataSource  \
# 653805  2019        MD  Maryland    Rockville      BRFSS
# 653908  2019        MD  Maryland    Rockville      BRFSS
# 653927  2019        MD  Maryland    Rockville      BRFSS
# 654508  2018        MD  Maryland    Rockville      BRFSS
# 654706  2019        MD  Maryland    Rockville      BRFSS
# 654783  2019        MD  Maryland    Rockville      BRFSS
# 654988  2019        MD  Maryland    Rockville      BRFSS
# 655223  2019        MD  Maryland    Rockville      BRFSS
# 655362  2019        MD  Maryland    Rockville      BRFSS
# 655576  2019        MD  Maryland    Rockville      BRFSS
# 656406  2018        MD  Maryland    Rockville      BRFSS
# 656744  2019        MD  Maryland    Rockville      BRFSS
# 656825  2019        MD  Maryland    Rockville      BRFSS
# 657091  2019        MD  Maryland    Rockville      BRFSS
# 657482  2019        MD  Maryland    Rockville      BRFSS
# ...

# %%
res = req.get('https://chronicdata.cdc.gov/resource/eav7-hnsx.csv')

# %%
pd.read_csv(res.text)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_37/3663183253.py in <module>
# ----> 1 pd.read_csv(res.text)
#
# /opt/conda/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
pd.read_csv()
# Out:
# b'"year","stateabbr","statedesc","locationname","datasource","category","measure","data_value_unit","data_value_type","data_value","data_value_footnote_symbol","data_value_footnote","low_confidence_limit","high_confidence_limit","totalpopulation","geolocation","locationid","categoryid","measureid","datavaluetypeid","short_question_text"\n"2019","AL","Alabama","Carlton","BRFSS","Health Outcomes","Stroke among adults aged >=18 years","%","Age-adjusted prevalence","5.9",,,"5.3","6.6","65","POINT (-87.8385235 31.34655389)","0112112","HLTHOUT","STROKE","AgeAdjPrv","Stroke"\n"2019","AL","Alabama","Chatom","BRFSS","Health Outcomes","Obesity among adults aged >=18 years","%","Crude prevalence","40.8",,,"39.5","42.0","1288","POINT (-88.24602114 31.46914557)","0114008","HLTHOUT","OBESITY","CrdPrv","Obesity"\n"2019","AL","Alabama","Collinsville","BRFSS","Health Outcomes","Stroke among adults aged >=18 years","%","Crude prevalence","5.3",,,"4.7","6.0","1983","POINT (-85.865567 34.26230655)","011
# ...

# %%
pd.read_csv('https://chronicdata.cdc.gov/resource/eav7-hnsx.csv')
# Out:
#      year stateabbr statedesc  locationname datasource         category  \
# 0    2019        AL   Alabama       Carlton      BRFSS  Health Outcomes
# 1    2019        AL   Alabama        Chatom      BRFSS  Health Outcomes
# 2    2019        AL   Alabama  Collinsville      BRFSS  Health Outcomes
# 3    2019        AL   Alabama        Colony      BRFSS  Health Outcomes
# 4    2019        AL   Alabama       Coosada      BRFSS  Health Outcomes
# ..    ...       ...       ...           ...        ...              ...
# 995  2019        NE  Nebraska         Brock      BRFSS  Health Outcomes
# 996  2019        NE  Nebraska   Cedar Creek      BRFSS  Health Outcomes
# 997  2019        NE  Nebraska      Chambers      BRFSS  Health Outcomes
# 998  2019        NE  Nebraska        Clarks      BRFSS  Health Outcomes
# 999  2019        NE  Nebraska       Concord      BRFSS  Health Outcomes
#
#                                      measure data_value_unit  \
# ...
